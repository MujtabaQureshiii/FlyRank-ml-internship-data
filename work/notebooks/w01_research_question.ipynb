# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
print("""
Lane: Structured Content Archetype Clustering

I chose this lane because I recently learned about clustering and found it interesting. 
My goal is to discover natural groups of content pages based on their search performance 
and engagement metrics. Instead of predicting future outcomes, I want to identify 
different content archetypes that can help content teams understand which pages are 
performing well, which may need improvement, and which should be monitored.
""")
# Out:
# Lane: Structured Content Archetype Clustering
#
# I chose this lane because I recently learned about clustering and found it interesting.
# My goal is to discover natural groups of content pages based on their search performance
# and engagement metrics. Instead of predicting future outcomes, I want to identify
# different content archetypes that can help content teams understand which pages are
# performing well, which may need improvement, and which should be monitored.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("""
Research Question:
What performance archetypes exist across the content inventory?

Decision:
Help content reviewers decide how different pages should be prioritized for review.

Unit of Analysis:
One content page.

Output:
Cluster assignments, cluster profiles, and suggested actions for each cluster.

Who acts on it?
Content reviewers, SEO analysts, and content managers.

Action:
Depending on the cluster, reviewers can decide to protect, refresh, improve,
monitor, merge, or prune pages.

Cost of a wrong recommendation:
If pages are placed in the wrong cluster, reviewers may spend time on pages that
do not need attention or overlook pages that actually require improvement,
reducing the efficiency of the review process.

Why ML helps:
Clustering can discover natural patterns across multiple performance metrics that
would be difficult to identify manually.
""")
# Out:
# Research Question:
# What performance archetypes exist across the content inventory?
#
# Decision:
# Help content reviewers decide how different pages should be prioritized for review.
#
# Unit of Analysis:
# One content page.
#
# Output:
# Cluster assignments, cluster profiles, and suggested actions for each cluster.
#
# Who acts on it?
# Content reviewers, SEO analysts, and content managers.
#
# Action:
# Depending on the cluster, reviewers can decide to protect, refresh, improve,
# monitor, merge, or prune pages.
#
# Cost of a wrong recommendation:
# If pages are placed in the wrong cluster, reviewers may spend time on pages that
# do not need attention or overlook pages that actually require improvement,
# reducing the efficiency of the review process.
#
# Why ML helps:
# Clustering can discover natural patterns across multiple performance metrics that
# would be difficult to identify manually.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average 90-day impressions:", round(df["impressions_90d"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 2))

print("\nWhy this supports my lane:")
print("The dataset contains enough pages and measurable search metrics to explore")
print("different performance patterns. These characteristics make clustering")
print("a suitable approach for identifying content archetypes.")
# Out:
# Number of pages: 30000
# Average 90-day impressions: 5200.37
# Average CTR: 0.51
#
# Why this supports my lane:
# The dataset contains enough pages and measurable search metrics to explore
# different performance patterns. These characteristics make clustering
# a suitable approach for identifying content archetypes.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("""
This project identifies groups of content pages with similar performance
characteristics. The clusters are intended to support content review and
prioritization by helping identify common content archetypes.

This project cannot prove that belonging to a cluster causes better or worse
performance. It cannot predict Google's ranking algorithm or guarantee that a
particular action will improve search performance. The results are intended to
support human decision-making, not replace it.
""")
# Out:
# This project identifies groups of content pages with similar performance
# characteristics. The clusters are intended to support content review and
# prioritization by helping identify common content archetypes.
#
# This project cannot prove that belonging to a cluster causes better or worse
# performance. It cannot predict Google's ranking algorithm or guarantee that a
# particular action will improve search performance. The results are intended to
# support human decision-making, not replace it.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
